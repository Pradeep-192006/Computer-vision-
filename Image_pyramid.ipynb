# %% [markdown]
# <a href="https://colab.research.google.com/github/Pradeep-192006/Computer-vision-/blob/main/Image_pyramid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ac04c6a7-f196-468a-927c-66ce3c5764fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac04c6a7-f196-468a-927c-66ce3c5764fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# ---------- Step 1: Read Image ----------
img = cv2.imread("Screenshot_2026_0123_121151.jpg")

# ❗ Safety check (most common error fix)
if img is None:
    raise FileNotFoundError("Image not found. Check file name or path.")

# Convert BGR to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# ---------- Step 2: Generate Pyramid Levels ----------
level1 = cv2.pyrDown(img)
level2 = cv2.pyrDown(level1)
level3 = cv2.pyrDown(level2)

images = [img, level1, level2, level3]
titles = ["Level 0 (Original)", "Level 1", "Level 2", "Level 3"]

# ---------- Step 3: Display Pyramid Images ----------
plt.figure(figsize=(10, 6))
for i in range(4):
    plt.subplot(2, 2, i + 1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis("off")

plt.tight_layout()
plt.show()

# ---------- Step 4: Print Image Sizes ----------
for i, im in enumerate(images):
    print(f"Level {i} image size: {im.shape}")

# ---------- Step 5: Edge Detection at Each Level ----------
for i, im in enumerate(images):
    gray = cv2.cvtColor(im, cv2.COLOR_RGB2GRAY)
    edges = cv2.Canny(gray, 100, 200)

    plt.figure(figsize=(4, 4))
    plt.imshow(edges, cmap="gray")
    plt.title(f"Edges at Pyramid Level {i}")
    plt.axis("off")
    plt.show()
# Out:
# Level 0 image size: (438, 706, 3)
# Level 1 image size: (219, 353, 3)
# Level 2 image size: (110, 177, 3)
# Level 3 image size: (55, 89, 3)
